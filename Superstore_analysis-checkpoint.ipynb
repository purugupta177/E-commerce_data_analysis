# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
db = pd.read_csv(r"C:\Users\PuruGupta\Documents\Kaggle\e_commerce\data.csv",encoding='unicode_escape')
db.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
db['InvoiceDate'] = pd.to_datetime(db['InvoiceDate'])
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
db.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
print("Lets drop all the NULL values from CustomerID\n____________________________")
db1 = db.dropna(subset='CustomerID')
db1.isnull().sum()
# Out:
# Lets drop all the NULL values from CustomerID
# ____________________________
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
print("There are a total of", len(db['Country'].unique()), "Countries present in our data")
print("Which are as follows \n__________________________________")

db1['Country'].unique()
# Out:
# There are a total of 38 Countries present in our data
# Which are as follows
# __________________________________
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Greece', 'Singapore', 'Lebanon',
#        'United Arab Emirates', 'Saudi Arabia', 'Czech Republic', 'Canada',
#        'Unspecified', 'Brazil', 'USA', 'European Community', 'Bahrain',
#        'Malta', 'RSA'], dtype=object)

# %%
print("Lets figure out the number of invoices for each country\n_______________________________________________")
db1.groupby(['Country']).size()
# Out:
# Lets figure out the number of invoices for each country
# _______________________________________________
# Country
# Australia                 1259
# Austria                    401
# Bahrain                     17
# Belgium                   2069
# Brazil                      32
# Canada                     151
# Channel Islands            758
# Cyprus                     622
# Czech Republic              30
# Denmark                    389
# EIRE                      7485
# European Community          61
# Finland                    695
# France                    8491
# Germany                   9495
# Greece                     146
# Iceland                    182
# Israel                     250
# Italy                      803
# Japan                      358
# Lebanon                     45
# Lithuania                   35
# Malta                      127
# Netherlands               2371
# Norway                    1086
# Poland                     341
# Portugal                  1480
# RSA                         58
# Saudi Arabia                10
# Singapore                  229
# Spain                     2533
# Sweden                     462
# Switzerland               1877
# USA                        291
# United Arab Emirates        68
# United Kingdom          361878
# Unspecified                244
# dtype: int64

# %%
print("We can see that there are 244 entries which doesn't have any countries information\nLet's drop such entries as well\n___________________________________________________________________")
db2 = db1[db1['Country'] != 'Unspecified']

db2.groupby(['Country']).size()
# Out:
# We can see that there are 244 entries which doesn't have any countries information
# Let's drop such entries as well
# ___________________________________________________________________
# Country
# Australia                 1259
# Austria                    401
# Bahrain                     17
# Belgium                   2069
# Brazil                      32
# Canada                     151
# Channel Islands            758
# Cyprus                     622
# Czech Republic              30
# Denmark                    389
# EIRE                      7485
# European Community          61
# Finland                    695
# France                    8491
# Germany                   9495
# Greece                     146
# Iceland                    182
# Israel                     250
# Italy                      803
# Japan                      358
# Lebanon                     45
# Lithuania                   35
# Malta                      127
# Netherlands               2371
# Norway                    1086
# Poland                     341
# Portugal                  1480
# RSA                         58
# Saudi Arabia                10
# Singapore                  229
# Spain                     2533
# Sweden                     462
# Switzerland               1877
# USA                        291
# United Arab Emirates        68
# United Kingdom          361878
# dtype: int64

# %%
cntry = db2.groupby(['Country']).size().reset_index(name='Count').sort_values(by='Count', ascending=False)
plt.bar(cntry['Country'],cntry['Count'])
plt.xlabel('Country')
plt.ylabel('Count')
plt.title('Count of Data by Country')
plt.xticks(rotation=90)
plt.show()
#cntry.plot(kind =

# %%
print("Considering that most of the sales goes in UK, we'll keep our discussion restricted to UK only for now")
db3 = db2[db2['Country']=='United Kingdom']
db3 = db3[db3['Sales']>=0]
db3.head()
# Out:
# Considering that most of the sales goes in UK, we'll keep our discussion restricted to UK only for now
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Month  Sales
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom     12  15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12  20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom     12  22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12  20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12  20.34

# %%
print("Total month wise sales is as follows\n_______________________________________________________")
db3['Month'] = db3['InvoiceDate'].dt.month
db3['Sales'] = db3['Quantity']*db3['UnitPrice']
month_wise_sales = db3.groupby('Month')['Sales'].sum().reset_index()
plt.bar(month_wise_sales['Month'],month_wise_sales['Sales'])
plt.xlabel('Month')
plt.ylabel('Sales')
plt.title('Month wise sales')
plt.show()
# Out:
# Total month wise sales is as follows
# _______________________________________________________

# %%
db3.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Month  Sales
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom     12  15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12  20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom     12  22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12  20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     12  20.34

# %%
top_prod_sold = db3.groupby('Description').size().reset_index()
top_prod_sold.rename(columns={0:'Count'}, inplace=True)
top_prod_sold.sort_values(by='Count',ascending=False, inplace=True)
top_1000_prod = top_prod_sold.head(20)
top_1000_prod
# Out:
#                              Description  Count
# 3666  WHITE HANGING HEART T-LIGHT HOLDER   1940
# 1747             JUMBO BAG RED RETROSPOT   1464
# 2740            REGENCY CAKESTAND 3 TIER   1426
# 213        ASSORTED COLOUR BIRD ORNAMENT   1333
# 2324                       PARTY BUNTING   1308
# 1927             LUNCH BAG RED RETROSPOT   1147
# 1919             LUNCH BAG  BLACK SKULL.   1049
# 2971   SET OF 3 CAKE TINS PANTRY DESIGN    1020
# 2292     PAPER CHAIN KIT 50'S CHRISTMAS     982
# 1595               HEART OF WICKER SMALL    952
# 2116     NATURAL SLATE HEART CHALKBOARD     951
# 2788        REX CASH+CARRY JUMBO SHOPPER    943
# 3293                      SPOTTY BUNTING    922
# 1922                 LUNCH BAG CARS BLUE    905
# 1929          LUNCH BAG SPACEBOY DESIGN     893
# 2248     PACK OF 72 RETROSPOT CAKE CASES    883
# 1926             LUNCH BAG PINK POLKADOT    873
# 1931              LUNCH BAG SUKI DESIGN     867
# 3730   WOODEN PICTURE FRAME WHITE FINISH    865
# 1745             JUMBO BAG PINK POLKADOT    831

# %%
top_sales = db3.groupby('Description').sum('Sales').reset_index()
top_sales = top_sales[['Description','Sales']]
top_sales.sort_values(by='Sales', ascending=False,inplace=True)
top_sales = top_sales.head(20)
top_sales
# Out:
#                              Description      Sales
# 2298         PAPER CRAFT , LITTLE BIRDIE  168469.60
# 2740            REGENCY CAKESTAND 3 TIER  110990.20
# 3666  WHITE HANGING HEART T-LIGHT HOLDER   94858.60
# 1975      MEDIUM CERAMIC TOP STORAGE JAR   80291.44
# 1747             JUMBO BAG RED RETROSPOT   77371.57
# 2324                       PARTY BUNTING   63109.38
# 213        ASSORTED COLOUR BIRD ORNAMENT   52395.99
# 717                        CHILLI LIGHTS   45505.31
# 2292     PAPER CHAIN KIT 50'S CHRISTMAS    40451.08
# 2373      PICNIC BASKET WICKER 60 PIECES   39619.50
# 369             BLACK RECORD COVER FRAME   37854.59
# 1005       DOORMAT KEEP CALM AND COME IN   34885.30
# 3714   WOOD BLACK BOARD ANT WHITE FINISH   33571.76
# 1745             JUMBO BAG PINK POLKADOT   33424.75
# 3293                      SPOTTY BUNTING   30159.25
# 1751                JUMBO BAG STRAWBERRY   28823.98
# 1594               HEART OF WICKER LARGE   28329.20
# 3502     VICTORIAN GLASS HANGING T-LIGHT   28015.11
# 1595               HEART OF WICKER SMALL   27561.54
# 2971   SET OF 3 CAKE TINS PANTRY DESIGN    25256.35

# %%
print("Products which have maximum sales as well as are sold most of the times\n_________________________________________")
new = top_sales.merge(top_1000_prod, on='Description', how='inner')
new
# Out:
# Products which have maximum sales as well as are sold most of the times
# _________________________________________
#                           Description      Sales  Count
# 0            REGENCY CAKESTAND 3 TIER  110990.20   1426
# 1  WHITE HANGING HEART T-LIGHT HOLDER   94858.60   1940
# 2             JUMBO BAG RED RETROSPOT   77371.57   1464
# 3                       PARTY BUNTING   63109.38   1308
# 4       ASSORTED COLOUR BIRD ORNAMENT   52395.99   1333
# 5     PAPER CHAIN KIT 50'S CHRISTMAS    40451.08    982
# 6             JUMBO BAG PINK POLKADOT   33424.75    831
# 7                      SPOTTY BUNTING   30159.25    922
# 8               HEART OF WICKER SMALL   27561.54    952
# 9   SET OF 3 CAKE TINS PANTRY DESIGN    25256.35   1020

# %%
print("Average number of things bought per order\nAverage number of things bought by cutomers\nAverage number of things bought by customer per invoice or order\nAverage sale value per invoice\nAverage sale value per customer\nAverage sale value per customer per invoice or order")
# Out:
# Average number of things bought per order
# Average number of things bought by cutomers
# Average number of things bought by customer per invoice or order
# Average sale value per invoice
# Average sale value per customer
# Average sale value per customer per invoice or order

# %%
#Average number of things bought per order
n = db3.groupby(['InvoiceNo']).sum('Sales').reset_index()
invoice_analysis = n[['InvoiceNo','Quantity','Sales']]
print("analysis of number of quantities in an invoice\n______________________________________")
print(invoice_analysis['Quantity'].describe())
print("__________________________________________________\nSuch high number of quantites per invoice indicates that this datbase contains bulk order values as well")
# Out:
# analysis of number of quantities in an invoice
# ______________________________________
# count    16649.000000
# mean       256.440147
# std        951.901975
# min          1.000000
# 25%         72.000000
# 50%        150.000000
# 75%        278.000000
# max      80995.000000
# Name: Quantity, dtype: float64
# __________________________________________________
# Such high number of quantites per invoice indicates that this datbase contains bulk order values as well

# %%
print("analysis of sales of quantities in an invoice\n______________________________________")
print(invoice_analysis['Sales'].describe())
# Out:
# analysis of sales of quantities in an invoice
# ______________________________________
# count     16649.000000
# mean        438.968800
# std        1663.352773
# min           0.000000
# 25%         152.820000
# 50%         299.520000
# 75%         444.360000
# max      168469.600000
# Name: Sales, dtype: float64

# %%
p = db3.groupby(['CustomerID','InvoiceNo'])['Sales'].sum().reset_index()
g = db3.groupby(['CustomerID','InvoiceNo'])['Quantity'].sum().reset_index()
m = p.merge(g,on=['CustomerID','InvoiceNo'],how='inner')
m
# Out:
#        CustomerID InvoiceNo     Sales  Quantity
# 0         12346.0    541431  77183.60     74215
# 1         12747.0    537215    358.56       108
# 2         12747.0    538537    347.71       105
# 3         12747.0    541677    303.04        88
# 4         12747.0    545321    310.78       146
# ...           ...       ...       ...       ...
# 16644     18283.0    579673    223.61       134
# 16645     18283.0    580872    208.00       142
# 16646     18287.0    554065    765.28       488
# 16647     18287.0    570715   1001.32       990
# 16648     18287.0    573167     70.68       108
#
# [16649 rows x 4 columns]
